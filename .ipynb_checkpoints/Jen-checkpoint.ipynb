# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
data_2013 = pd.read_csv("2013_APD_Traffic_Fatalities.csv")
data_2013
# Out:
#              Type  FATAL CRASH #  Number of Fatalities CASE NUMBER  \
# 0      Motorcycle              1                     2  13-0011875
# 1   Motor Vehicle              2                     1  13-0030199
# 2   Motor Vehicle              3                     1  13-0080360
# 3   Motor Vehicle              4                     1  13-0150689
# 4   Motor Vehicle              5                     1   13-181143
# ..            ...            ...                   ...         ...
# 67     Pedestrian             68                     1  13-3311692
# 68     Pedestrian             69                     1  13-3330477
# 69     Pedestrian             70                     1  13-3411356
# 70  Motor Vehicle             71                     2  13-3611885
# 71  Motor Vehicle             72                     1  13-3641035
#
#                     LOCATION     AREA        Date Month  Day  Hour  ...  \
# 0             1100 Berger St  Charlie  01/01/2013   Jan  Tue    18  ...
# ...

# %%
data_2013.Type.unique()
# Out:
# array(['Motorcycle', 'Motor Vehicle', 'Pedestrian', 'BICYCLE'],
#       dtype=object)

# %%
data_2014 = pd.read_csv("2014_APD_Traffic_Fatalities.csv")
data_2014
# Out:
#              TYPE  FATAL CRASH #  Number of Fatalities CASE NUMBER  \
# 0   Motor Vehicle              1                     2  14-0030146
# 1   Motor Vehicle              2                     1  14-0121394
# 2   Motor Vehicle              3                     2   14-350943
# 3   Motor Vehicle              4                     1   14-401238
# 4   Motor Vehicle              5                     1   14-420154
# 5      Motorcycle              6                     1  14-0531384
# 6      Pedestrian              7                     1  14-0511533
# 7      Pedestrian              8                     1  14-0610300
# 8      Motorcycle              9                     1   14-711395
# 9      Motorcycle             10                     1   14-720068
# 10     Pedestrian             10                     1   14-720068
# 11        Bicycle             10                     1   14-720068
# 12     Pedestrian             10                     1   14-720068
# ...

# %%
data_2015 = pd.read_csv("2015_APD_Traffic_Fatalities.csv")
data_2015
# Out:
#              TYPE  FATAL CRASH #  Number of Fatalities CASE NUMBER  \
# 0   Motor Vehicle              1                     1  15-0061199
# 1      Pedestrian              2                     1    15-71386
# 2      Pedestrian              3                     1   15-100275
# 3      Motorcycle              4                     1   15-131517
# 4   Motor Vehicle              5                     1   15-150104
# ..            ...            ...                   ...         ...
# 88  Motor Vehicle             90                     1  15-3640128
# 89  Motor Vehicle             91                     1  15-3640244
# 90     Motorcycle             92                     1  15-3641425
# 91  Motor Vehicle             93                     1  15-3601318
# 92     Motorcycle             94                     1  15-3650652
#
#                     LOCATION AREA        Date Month   Day  Hour  ...  \
# 0      600 Blk E Koenig Lane   ID  01/06/2015   Jan  Tues    17  ...
# ...

# %%
data_2016 = pd.read_csv("2016_APD_Traffic_Fatalities.csv")
data_2016
# Out:
#              TYPE  FATAL CRASH Number  Number of Fatalities CASE NUMBER  \
# 0      Pedestrian                   1                     1  16-0061621
# 1      Pedestrian                   2                     1  16-0140992
# 2   Motor Vehicle                   3                     1  16-0221932
# 3      Pedestrian                   4                     1  16-0301529
# 4      Motorcycle                   5                     1  16-0450263
# ..            ...                 ...                   ...         ...
# 72  Motor Vehicle                  73                     1  16-3530419
# 73  Motor Vehicle                  74                     1  16-3560215
# 74     Pedestrian                  75                     1  16-3561018
# 75     Pedestrian                  76                     1  16-3581664
# 76     Pedestrian                  77                     1  16-3301144
#
#                              LOCATION AREA        Date Month  Day  Hour  ...  \
# ...

# %%
data_2017 = pd.read_csv("2017_APD_Traffic_Fatalities.csv")
data_2017
# Out:
#              Type  Fatal crash number  Number of Fatalities Case Number  \
# 0   Motor Vehicle                   1                     1  17-0030106
# 1         Bicycle                   2                     1  17-0080877
# 2   Motor Vehicle                   3                     1  17-0071308
# 3   Motor Vehicle                   4                     1  17-0150225
# 4      Pedestrian                   5                     1  17-0110340
# ..            ...                 ...                   ...         ...
# 66     Motorcycle                  67                     1  17-3380841
# 67     Motorcycle                  68                     1  17-3390056
# 68  Motor Vehicle                  69                     1  17-3410022
# 69     Motorcycle                  70                     1  17-3460912
# 70  Motor Vehicle                  71                     1  17-3550122
#
#                                   Location Area        Date Month  Day  Hour  \
# ...

# %%
data_2018 = pd.read_csv("2018_APD_Traffic_Fatality_Data_021219.csv")
data_2018
# Out:
#              Type  Fatal Crash Number  Number of Fatalities Case Status  \
# 0   MOTOR VEHICLE                   1                     2      Closed
# 1   MOTOR VEHICLE                   2                     1      Closed
# 2      Motorcycle                   3                     1      Closed
# 3   MOTOR VEHICLE                   4                     1      Closed
# 4      Pedestrian                   5                     1        open
# ..            ...                 ...                   ...         ...
# 68  MOTOR VEHICLE                  70                     1        open
# 69     Pedestrian                  71                     1        open
# 70  MOTOR VEHICLE                  72                     1        open
# 71     Motorcycle                  73                     1        open
# 72  MOTOR VEHICLE                  74                     1        open
#
#    Case Number                                         Location Area  \
# ...

# %%
result = pd.concat([data_2013, data_2014], ignore_index=True, sort=False)
result
# Out:
#               Type  FATAL CRASH #  Number of Fatalities CASE NUMBER  \
# 0       Motorcycle              1                     2  13-0011875
# 1    Motor Vehicle              2                     1  13-0030199
# 2    Motor Vehicle              3                     1  13-0080360
# 3    Motor Vehicle              4                     1  13-0150689
# 4    Motor Vehicle              5                     1   13-181143
# ..             ...            ...                   ...         ...
# 126            NaN             52                     1  14-3281561
# 127            NaN             53                     1  14-3340356
# 128            NaN             54                     1  14-3371605
# 129            NaN             55                     1  14-3540447
# 130            NaN             56                     1  14-3610910
#
#                      LOCATION     AREA        Date Month  Day  Hour  ...  \
# 0              1100 Berger St  Charlie  01/01/2013   Jan  Tue    18  ...
# ...
